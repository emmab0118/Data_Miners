# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('accident.csv')
df.columns
#target max_sev im assuming
df.head(5)
# Out:
#         CASENUM  PSU  PSU_VAR  PSUSTRAT  REGION  \
# 0  202304632910   39       39         7       2
# 1  202304632916   77       77         9       2
# 2  202304635310   48       48        12       3
# 3  202304635315   48       48        12       3
# 4  202304635387   48       48        12       3
#
#                                           REGIONNAME  URBANICITY  \
# 0  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...           1
# 1  Midwest (OH, IN, IL, MI, WI, MN, ND, SD, NE, I...           2
# 2  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...           1
# 3  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...           1
# 4  South (MD, DE, DC, WV, VA, KY, TN, NC, SC, GA,...           1
#
#   URBANICITYNAME  STRATUM                        STRATUMNAME  ...  MAXSEV_IM  \
# 0     Urban Area       10                 Stratum 10 - Other  ...          0
# 1     Rural Area       10                 Stratum 10 - Other  ...          0
# ...

# %% [markdown]
# Some potential tasks?
# - train/test split
# - feature selection:
#    - filters/wrappers for analyzing feature relevance to target? we could try one of each to see how performance compares?
# - model selection: we already know what models we are using, we could assign each person a model to develop and then compare and analyze results
#     - log reg, decision tree, random forest, etc.
# - model evaluation (diff for each model)
#    - mean abs error, mean squared error, root mean squared, R2, etc.
#    - log reg likelihood ratio, R^2, etc
#    - decision tree, we can try IG and gini and analyze accuracy differences if any; build validation curve v. tree depth to find ideal depth?
#    - which model performed the "best"?
